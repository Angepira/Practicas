# %%
import pandas as pd

pacientes= pd.read_csv('Pacientes2.csv')
pacientes
# Out:
#      NOEXPED Enfermedad  HIPERTEN  HIPERGLU  HDLBAJA  HIPERTRI  CINTALTA  \
# 0          1         NO         0         0        1         0         0
# 1          2         SI         0         1        1         1         1
# 2          3         SI         1         1        0         1         1
# 3          4         NO         1         1        0         0         0
# 4          5         NO         0         0        1         0         0
# ..       ...        ...       ...       ...      ...       ...       ...
# 980      890         SI         1         1        1         0         0
# 981      892         NO         0         0        0         0         0
# 982      904         NO         1         0        1         1         0
# 983      954         NO         1         0        1         0         0
# 984      909         SI         1         0        0         1         1
#
#      EDAD  GENERO  FUMA  ALCOHOL  POLIURIA
# 0      38       0     0        0         0
# ...

# %%
pacientes=pacientes.set_index('NOEXPED')
pacientes
# Out:
#         Enfermedad  HIPERTEN  HIPERGLU  HDLBAJA  HIPERTRI  CINTALTA  EDAD  \
# NOEXPED
# 1               NO         0         0        1         0         0    38
# 2               SI         0         1        1         1         1    49
# 3               SI         1         1        0         1         1    59
# 4               NO         1         1        0         0         0    44
# 5               NO         0         0        1         0         0    42
# ...            ...       ...       ...      ...       ...       ...   ...
# 890             SI         1         1        1         0         0    70
# 892             NO         0         0        0         0         0    39
# 904             NO         1         0        1         1         0    45
# 954             NO         1         0        1         0         0    41
# 909             SI         1         0        0         1         1    73
#
#          GENERO  FUMA  ALCOHOL  POLIURIA
# NOEXPED
# ...

# %%
pacientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 985 entries, 1 to 909
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Enfermedad  985 non-null    object
#  1   HIPERTEN    985 non-null    int64
#  2   HIPERGLU    985 non-null    int64
#  3   HDLBAJA     985 non-null    int64
#  4   HIPERTRI    985 non-null    int64
#  5   CINTALTA    985 non-null    int64
#  6   EDAD        985 non-null    int64
#  7   GENERO      985 non-null    int64
#  8   FUMA        985 non-null    int64
#  9   ALCOHOL     985 non-null    int64
#  10  POLIURIA    985 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 92.3+ KB

# %%
X=pacientes.iloc[:,1:11]
X
# Out:
#          HIPERTEN  HIPERGLU  HDLBAJA  HIPERTRI  CINTALTA  EDAD  GENERO  FUMA  \
# NOEXPED
# 1               0         0        1         0         0    38       0     0
# 2               0         1        1         1         1    49       1     0
# 3               1         1        0         1         1    59       1     0
# 4               1         1        0         0         0    44       0     0
# 5               0         0        1         0         0    42       0     0
# ...           ...       ...      ...       ...       ...   ...     ...   ...
# 890             1         1        1         0         0    70       1     0
# 892             0         0        0         0         0    39       0     0
# 904             1         0        1         1         0    45       0     0
# 954             1         0        1         0         0    41       0     0
# 909             1         0        0         1         1    73       1     0
#
#          ALCOHOL  POLIURIA
# ...

# %%
y=pacientes.iloc[:,0]
y
# Out:
# NOEXPED
# 1      NO
# 2      SI
# 3      SI
# 4      NO
# 5      NO
#        ..
# 890    SI
# 892    NO
# 904    NO
# 954    NO
# 909    SI
# Name: Enfermedad, Length: 985, dtype: object

# %%
from sklearn.model_selection import train_test_split

datos_train, datos_test, clase_train, clase_test=train_test_split(X,y,test_size=0.2)
datos_train
# Out:
#          HIPERTEN  HIPERGLU  HDLBAJA  HIPERTRI  CINTALTA  EDAD  GENERO  FUMA  \
# NOEXPED
# 319             0         0        1         0         0    18       1     1
# 894             0         0        1         0         0    45       0     1
# 939             1         0        1         1         1    39       1     0
# 463             0         0        0         0         1    45       0     1
# 53              0         1        0         1         0    49       1     0
# ...           ...       ...      ...       ...       ...   ...     ...   ...
# 55              0         1        0         1         1    46       0     0
# 349             0         0        1         1         1    19       0     0
# 988             0         0        1         0         0    29       0     0
# 85              0         1        1         0         1    42       0     0
# 471             1         0        1         0         0    44       0     0
#
#          ALCOHOL  POLIURIA
# ...

# %%
clase_test
# Out:
# NOEXPED
# 774    NO
# 296    NO
# 8      NO
# 216    SI
# 422    SI
#        ..
# 481    NO
# 631    NO
# 392    NO
# 118    SI
# 472    SI
# Name: Enfermedad, Length: 197, dtype: object

# %%
from sklearn import tree

arbol_dec=tree.DecisionTreeClassifier(max_depth=5)
arbol_dec.fit(datos_train,clase_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
presicion= arbol_dec.score(datos_test,clase_test)
presicion
# Out:
# 0.9695431472081218

# %%
import matplotlib.pyplot as plt

print(tree.export_text(arbol_dec,feature_names=list(X.columns.values)))
plt.figure(figsize=(12,8))
tree.plot_tree(arbol_dec, feature_names=list(X.columns.values), class_names=list(y.values), filled=True)
plt.show()
# Out:
# |--- CINTALTA <= 0.50
# |   |--- HIPERGLU <= 0.50
# |   |   |--- HIPERTEN <= 0.50
# |   |   |   |--- EDAD <= 47.50
# |   |   |   |   |--- class: NO
# |   |   |   |--- EDAD >  47.50
# |   |   |   |   |--- EDAD <= 48.50
# |   |   |   |   |   |--- class: NO
# |   |   |   |   |--- EDAD >  48.50
# |   |   |   |   |   |--- class: NO
# |   |   |--- HIPERTEN >  0.50
# |   |   |   |--- HIPERTRI <= 0.50
# |   |   |   |   |--- class: NO
# |   |   |   |--- HIPERTRI >  0.50
# |   |   |   |   |--- HDLBAJA <= 0.50
# |   |   |   |   |   |--- class: NO
# |   |   |   |   |--- HDLBAJA >  0.50
# |   |   |   |   |   |--- class: NO
# |   |--- HIPERGLU >  0.50
# |   |   |--- HIPERTRI <= 0.50
# |   |   |   |--- HIPERTEN <= 0.50
# |   |   |   |   |--- class: NO
# |   |   |   |--- HIPERTEN >  0.50
# |   |   |   |   |--- HDLBAJA <= 0.50
# |   |   |   |   |   |--- class: NO
# |   |   |   |   |--- HDLBAJA >  0.50
# |   |   |   |   |   |--- class: SI
# |   |   |--- HIPERTRI >  0.50
# ...

# %%
Y_pred= arbol_dec.predict(datos_test)
Y_pred
# Out:
# array(['NO', 'NO', 'NO', 'SI', 'SI', 'NO', 'NO', 'NO', 'SI', 'NO', 'NO',
#        'NO', 'NO', 'NO', 'NO', 'SI', 'NO', 'NO', 'NO', 'NO', 'SI', 'NO',
#        'SI', 'SI', 'NO', 'NO', 'NO', 'NO', 'SI', 'NO', 'SI', 'NO', 'NO',
#        'SI', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'SI', 'NO', 'NO',
#        'NO', 'NO', 'SI', 'NO', 'SI', 'NO', 'NO', 'SI', 'NO', 'NO', 'SI',
#        'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO',
#        'NO', 'NO', 'NO', 'SI', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO',
#        'NO', 'SI', 'NO', 'NO', 'NO', 'NO', 'NO', 'SI', 'SI', 'SI', 'NO',
#        'NO', 'NO', 'SI', 'NO', 'NO', 'NO', 'NO', 'SI', 'NO', 'NO', 'SI',
#        'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'SI', 'NO', 'NO', 'SI', 'NO',
#        'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'SI', 'SI', 'NO',
#        'SI', 'NO', 'SI', 'NO', 'NO', 'NO', 'NO', 'NO', 'SI', 'NO', 'NO',
#        'SI', 'NO', 'NO', 'SI', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO',
# ...

# %%
from sklearn.metrics import confusion_matrix

matriz=confusion_matrix(clase_test,Y_pred)
print(matriz)
# Out:
# [[141   0]
#  [  6  50]]
